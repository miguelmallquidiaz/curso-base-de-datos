# %% [markdown]
# ## Clave foranea

# %% [markdown]
# Mostrar la etiqueta de relacción
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Activar el diseñador de tablas
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Eliminar de forma gráfica la realción pero hasta no se guardan los cambios
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Nomenclatura para la FK
#
# Si es diferente el código identificador
#
# fk + esquema + tabla + campo identificador de fk + esquema + tabla + campo identificador de pk
#
# Si es que estan en la mismo esquema y tiene el mismo nombre de identificador
#
# fk + esquema  + tabla1 + tabla2 + campo identificador
#
#
# fk_personal_empleado_rol_cod_rol_in
