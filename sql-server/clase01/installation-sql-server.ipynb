# %% [markdown]
# ## Verificar el tipo de maquina
#
# En configuración --> Sistema --> Acerda de
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cambiar el idioma
#
# En panel de control --> Sistema y seguridad --> Herramientas administrativas --> Administración de equipos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ingresar a la carpeta usuarios, en administrador se va a propiedades se le quita la casilla cuenta desabilitada y aplicar los cambios.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ponerle contraseña al administrador
#
# La contraseña es miguel
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Cambiar de cuenta a administrador
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Verificar La región debe estar en españa
#
# ![región-españa.PNG](attachment:región-españa.PNG)
#
# ![idioma-españa.PNG](attachment:idioma-españa.PNG)
#
# ![panel-de-control-región-españa.PNG](attachment:panel-de-control-región-españa.PNG)
#
# ![configuración-regional-españa.PNG](attachment:configuración-regional-españa.PNG)
#
# ![copiar-configuración.png](attachment:copiar-configuración.png)

# %% [markdown]
# ## Descargar Sql Sever Developer 2022
#
# https://www.microsoft.com/es-es/sql-server/sql-server-downloads
#
# ![descargar-developer.png](attachment:descargar-developer.png)

# %% [markdown]
# Ejecutar como administrador
#
# ![instalar-como-administrador.png](attachment:instalar-como-administrador.png)

# %% [markdown]
# Ir a nueva instalación
#
# ![nueva-instalación.png](attachment:nueva-instalación.png)

# %% [markdown]
# Seleccionar personalizado
#
# ![personalizado.png](attachment:personalizado.png)

# %% [markdown]
# Edición darle a siguiente
#
# ![siguiente.png](attachment:siguiente.png)

# %% [markdown]
# Terminos de licencia, aceptar y darle a siguiente
#
# ![politica.png](attachment:politica.png)

# %% [markdown]
# Instalación de reglas
#
# ![instalar-reglas.png](attachment:instalar-reglas.png)

# %% [markdown]
# Desabilitar la opción de azure
#
# ![desabilitar-azure.png](attachment:desabilitar-azure.png)

# %% [markdown]
# Seleccionar todo menos el PolyBase que es con Oracle
#
# ![caracteristicas.png](attachment:caracteristicas.png)

# %% [markdown]
# Siguiente
#
# ![configuración-de-instancia.png](attachment:configuración-de-instancia.png)

# %% [markdown]
# Desabilitar todo
#
# ![configuración-del-servidor.png](attachment:configuración-del-servidor.png)

# %% [markdown]
# Configuración del Motor de base de datos, se debe agregar un nuevo usuario actual
#
# ![configuración-del-servidor-add-user.png](attachment:configuración-del-servidor-add-user.png)

# %% [markdown]
# Luego de agregar al administrador se seleciona agregar para otros ususarios, se debe esperar a que cuando le des aceptar salga el nombre del usuario agregado ya luego darle a siguiente.
#
# ![configuración-motor-de-base-de-datos.png](attachment:configuración-motor-de-base-de-datos.png)

# %% [markdown]
# Configuración de Analysis Services, se realiza los mismo pasos que arriba y se selecciona la opción multidimensional
#
# ![configuración-de-analysis-services.png](attachment:configuración-de-analysis-services.png)

# %% [markdown]
# Configuración de escalabilidad horizontal se le deja por defecto y siguiente
#
# ![certificado.png](attachment:certificado.png)
#
# ![configuración-de-escalabilidad.png](attachment:configuración-de-escalabilidad.png)

# %% [markdown]
# Darle a instalar
#
# ![listo-para-instalar.png](attachment:listo-para-instalar.png)

# %% [markdown]
# Operación completa, todo debe estar correctamente instalado
#
# ![operación-completa-todo-en-verde.png](attachment:operación-completa-todo-en-verde.png)

# %% [markdown]
# ## Instalación de Management Studio (SSMS)
#
# https://learn.microsoft.com/es-es/sql/ssms/download-sql-server-management-studio-ssms?view=sql-server-ver16
#
# Descargar la versión en Español
#
# ![instalar-management-studio.png](attachment:instalar-management-studio.png)
#
# Ejecutar como administrador
#
# ![instalar-como-administrador.png](attachment:instalar-como-administrador.png)
#
# Darle a Instalar
#
# ![inicio-instalar.png](attachment:inicio-instalar.png)
#
# Cerrar
#
# ![instalación-completa.png](attachment:instalación-completa.png)
#
# En servicios poner todo desabilitado nada en automático ya que consume mucha memoria
#
# ![deshabilitar-servicios.png](attachment:deshabilitar-servicios.png)

# %% [markdown]
# ## Conectarse con el servidor
#
# Se debe tener activo SQL SERVER (MSSQLSERVER) en ejecución y se debe confiar en el certificado del servidor
#
# ![conectar-sql.png](attachment:conectar-sql.png)
