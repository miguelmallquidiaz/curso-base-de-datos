# %% [markdown]
# ## Restauración de la base de datos

# %% [markdown]
# Descargar la base de datos AdventureWorks 2019 https://learn.microsoft.com/en-us/sql/samples/adventureworks-install-configure?view=sql-server-ver16&tabs=ssms
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Esquemas
#
# Es una forma de agrupar y organizar los objetos de la base de datos tal como es la tabla y vistas. Solo los grupos de usuarios que tienen acceso van a poder visualizar y gestionar las tablas.

# %% [markdown]
# ## Descargar la base de datos CONTOSO
#
# Link de descarga: https://www.microsoft.com/es-es/download/details.aspx?id=18279
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Desempaquetar
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## PRIMARY KEY
#
# EL primary key debe ser de tipo númerico ya que la performace debe ser rápido al momento de buscar
# Hay otro campo que se le pone como alternate key es donde va el código como 'R001'
#
# Es de tipo cluster esta ordenado fisicamente en el disco, es decir ordena los registro de la tabla
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cambiar el nombre de la PK
#
# Se utiliza constraint
#
# Formas de colocar el nombre a la clave primaria
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Cambiar el esquema en vez de dbo.
#
# Solamente se puede ejecutar 1 vez
#
# ![image.png](attachment:image.png)

# %% [markdown]
# DROP elimina toda la tabla o base de datos.
# <br>DELETE elimina datos dentro de la tabla, pero no la tabla misma.
