# %% [markdown]
# ## Restauración de la base de datos

# %% [markdown]
# Descargar la base de datos AdventureWorks 2019 https://learn.microsoft.com/en-us/sql/samples/adventureworks-install-configure?view=sql-server-ver16&tabs=ssms
#
# ![image.png](attachment:image.png)

# %% [markdown]
# OLTP (Online Transaction Processing):
# Se utiliza cuando es necesario realizar operaciones de transacciones en tiempo real de manera constante. Este tipo de sistemas está optimizado para manejar una gran cantidad de operaciones simultáneas, como inserciones, actualizaciones y eliminaciones de datos, garantizando la integridad de las transacciones.
#
# Tabla hecho fact
# Datamart
# Copo de nieve
# Medidas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Esquemas
#
# Es un contenedir que va a permitir categorizar
