# %% [markdown]
# ## ¿Qué es SQL?

# %% [markdown]
# Es un lenguaje declarativo que yo especifico que operación voy a realizar y el sistema de gestión de base de datos (DBMS) se encarga de ejecutar las operaciones.

# %% [markdown]
# ## Subconjunto del lenguaje

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Instalación de SQL SERVER 2022 DEVELOPER

# %% [markdown]
# Primero verificamos la configuración regional
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Descargar SQL Server
#
# https://www.microsoft.com/es-es/sql-server/sql-server-downloads
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejecutar como administrador
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Elegir el de personalizado
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Este mensaje sale si no tenemos la versión pro de la licencia de Windows
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Darle a instalar
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Seleccionar nueva instalación
#
# ![image.png](attachment:image.png)

# %% [markdown]
# siguiente
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Aceptar los terminos siguiente
#
# ![image.png](attachment:image.png)

# %% [markdown]
# resultados y darle a siguiente
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Desactivar extensión de azure
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Seleccionar todo y quitar el PolyBase
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Siguiente
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Marcamos los privilegios
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Es recomendable no trabajar como administración solo en la instalación ya que una página puede traer virus
#
# Agregar administrador
#
# ![image.png](attachment:image.png)
#
# Añadir mi usuario
#
# ![image-2.png](attachment:image-2.png)
#
# Buscar al usuario y agregar
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Seleccionar el modo mixto de autentificación ponerle una contraseña que va a ser admin1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Seleccionar modo multidimensional y darle permiso a los 2 tipo de usuarios
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Siguiente
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Al finalizar sale de esta forma
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Descargar SQL Server Management Studio (SSMS) en inglés
#
# https://learn.microsoft.com/es-es/sql/ssms/download-sql-server-management-studio-ssms?view=sql-server-ver16
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Una vez descargado ejecutar como administrador
#
# Darle a instalar
#
# ![image-2.png](attachment:image-2.png)
